# %% [markdown]
# # Critical Introduction to Natural Language Processing

# %% [markdown]
# Using only the raw text, we'll derive and explore the semantic properties of its words.

# %% [markdown]
# ## Imports

# %% [markdown]
# Python code in one module gains access to the code in another module by the process of importing it. The import statement is the most common way of invoking the import machinery, but it is not the only way.

# %%
from __future__ import absolute_import, division, print_function

# %% [markdown]
# First we import common system-tools etc. here that are not directly connected to NLP

# %%
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re

# %%
import nltk
import gensim.models.word2vec as w2v
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
import sklearn.manifold
from sklearn.manifold import TSNE
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# D:\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# You will probably run into an "ModuleNorFoundError" here. THis means that the needed module is not installed on your system.
# You can do that in the anaconda command prompt:
# for example: <b>"conda install -c anaconda nltk"</b> or <b>"conda install -c anaconda gensim"</b> and <b>"conda install -c conda-forge glob2"</b> <br> for detailed information refer to https://docs.anaconda.com/anaconda/user-guide/tasks/install-packages/ <br>

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Set up logging**

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# **Download NLTK tokenizer models (only the first time)**

# %%
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\fmx\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fmx\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Prepare Corpus

# %% [markdown]
# **Load books from files**

# %%
book_filenames = sorted(glob.glob("txtdata\*.txt"))

# %%
print("Found books:")
book_filenames
# Out:
# Found books:
# ['txtdata\\truth-and-method-gadamer-2004.txt']

# %% [markdown]
# **Combine the books into one string**

# %%
corpus_raw = u""
for book_filename in book_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading 'txtdata\truth-and-method-gadamer-2004.txt'...
# Corpus is now 1618721 characters long

# %% [markdown]
# **Build your vocabulary (word tokenization)**

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %% [markdown]
# Given a character sequence and a defined document unit, tokenization is the task of chopping it up into pieces, called tokens , perhaps at the same time throwing away certain characters, such as punctuation.

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
#convert into a list of words
#rtemove unnnecessary,, split into words, no hyphens
#list of words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[5])
print(sentence_to_wordlist(raw_sentences[5]))
# Out:
# The hermeneutic phenomenon is
# basically not a problem of method at all.
# ['The', 'hermeneutic', 'phenomenon', 'is', 'basically', 'not', 'a', 'problem', 'of', 'method', 'at', 'all']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 260,890 tokens

# %% [markdown]
# ## Train Word2Vec

# %% [markdown]
# Word2vec is a method of computing vector representations of words introduced by a team of researchers at Google led by Tomas Mikolov. Google hosts an open-source version of Word2vec released under an Apache 2.0 license. In 2014, Mikolov left Google for Facebook, and in May 2015, Google was granted a patent for the method, which does not abrogate the Apache license under which it has been released. <br>
#
# <b>Foreign Languages</b> <br>
#
# While words in all languages may be converted into vectors with Word2vec, and those vectors learned with deep-learning frameworks, NLP preprocessing can be very language specific, and requires tools beyond our libraries. The Stanford Natural Language Processing Group has a number of Java-based tools for tokenization, part-of-speech tagging and named-entity recognition for languages such as Mandarin Chinese, Arabic, French, German and Spanish. For Japanese, NLP tools like Kuromoji are useful. Other foreign-language resources, including text corpora, are available here.
# http://www-nlp.stanford.edu/links/statnlp.html

# %%
size = 160
window = 10
min_count = 2
workers = multiprocessing.cpu_count()
sg=1
seed = 1
sample = 1e-3
iter = 5

# %% [markdown]
# <b>size (int, optional)</b> – Dimensionality of the word vectors.
#
# <b>window (int, optional)</b> – Maximum distance between the current and predicted word within a sentence.
#
# <b>min_count (int, optional)</b> – Ignores all words with total frequency lower than this.
#
# <b>workers (int, optional)</b> – Use these many worker threads to train the model (=faster training with multicore machines).
#
# <b>sg ({0, 1}, optional)</b> – Training algorithm: 1 for skip-gram; otherwise CBOW.
#
# <b>seed (int, optional)</b> – Seed for the random number generator. Initial vectors for each word are seeded with a hash of the concatenation of word + str(seed). Note that for a fully deterministically-reproducible run, you must also limit the model to a single worker thread (workers=1), to eliminate ordering jitter from OS thread scheduling. (In Python 3, reproducibility between interpreter launches also requires use of the PYTHONHASHSEED environment variable to control hash randomization).
#
# <b>sample (float, optional)</b> – The threshold for configuring which higher-frequency words are randomly downsampled, useful range is (0, 1e-5).
#
# <b>iter (int, optional)</b> – Number of iterations (epochs) over the corpus.
#
# https://radimrehurek.com/gensim/models/word2vec.html

# %%
word2vec = w2v.Word2Vec(
    size = size,
    window = window,
    min_count = min_count,
    workers = workers,
    sg = sg,
    seed = seed,
    sample = sample,
    iter = iter
)

# %%
word2vec.build_vocab(sentences)
# Out:
# 2019-11-13 17:13:44,594 : INFO : collecting all words and their counts
# 2019-11-13 17:13:44,595 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-11-13 17:13:44,633 : INFO : PROGRESS: at sentence #10000, processed 223470 words, keeping 11480 word types
# 2019-11-13 17:13:44,639 : INFO : collected 12895 word types from a corpus of 260890 raw words and 11459 sentences
# 2019-11-13 17:13:44,639 : INFO : Loading a fresh vocabulary
# 2019-11-13 17:13:44,695 : INFO : min_count=2 retains 7334 unique words (56% of original 12895, drops 5561)
# 2019-11-13 17:13:44,696 : INFO : min_count=2 leaves 255329 word corpus (97% of original 260890, drops 5561)
# 2019-11-13 17:13:44,714 : INFO : deleting the raw counts dictionary of 12895 items
# 2019-11-13 17:13:44,715 : INFO : sample=0.001 downsamples 45 most-common words
# 2019-11-13 17:13:44,716 : INFO : downsampling leaves estimated 185415 word corpus (72.6% of prior 255329)
# 2019-11-13 17:13:44,730 : INFO : estimated required memory for 7334 words and 160 dimensions: 13054520 bytes
# 2019-11-13 17:13:44,731 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(word2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 7334

# %% [markdown]
# **Start training, this might take a minute or two...**

# %%
word2vec.train(sentences, total_words=token_count, epochs = 10 )
# Out:
# 2019-11-13 17:13:45,921 : INFO : training model with 8 workers on 7334 vocabulary and 160 features, using sg=1 hs=0 sample=0.001 negative=5 window=10
# 2019-11-13 17:13:46,268 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-13 17:13:46,269 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-13 17:13:46,273 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-13 17:13:46,281 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-13 17:13:46,284 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-13 17:13:46,286 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-13 17:13:46,321 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-13 17:13:46,329 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-13 17:13:46,330 : INFO : EPOCH - 1 : training on 260890 raw words (185225 effective words) took 0.4s, 468561 effective words/s
# 2019-11-13 17:13:46,650 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-13 17:13:46,658 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-13 17:13:46,667 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-13 17:13:46,670 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-13 17:13:46,671 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-13 17:13:46,685 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-13 17:13:46,709 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-13 17:13:46,715 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-13 17:13:46,716 : INFO : EPOCH - 2 : training on 260890 raw words (185584 effective words) took 0.4s, 491505 effective words/s
# 2019-11-13 17:13:47,023 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-13 17:13:47,024 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-13 17:13:47,031 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-13 17:13:47,032 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-13 17:13:47,045 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-13 17:13:47,050 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-13 17:13:47,095 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-13 17:13:47,098 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-13 17:13:47,099 : INFO : EPOCH - 3 : training on 260890 raw words (185197 effective words) took 0.4s, 497012 effective words/s
# 2019-11-13 17:13:47,401 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-13 17:13:47,404 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-13 17:13:47,410 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-13 17:13:47,416 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-13 17:13:47,418 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-13 17:13:47,424 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-13 17:13:47,459 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-13 17:13:47,460 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-13 17:13:47,461 : INFO : EPOCH - 4 : training on 260890 raw words (185358 effective words) took 0.4s, 527903 effective words/s
# 2019-11-13 17:13:47,813 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-13 17:13:47,815 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-13 17:13:47,821 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-13 17:13:47,834 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-13 17:13:47,835 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-13 17:13:47,853 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-13 17:13:47,879 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-13 17:13:47,883 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-13 17:13:47,884 : INFO : EPOCH - 5 : training on 260890 raw words (185379 effective words) took 0.4s, 449539 effective words/s
# 2019-11-13 17:13:48,212 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-13 17:13:48,214 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-13 17:13:48,218 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-13 17:13:48,225 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-13 17:13:48,237 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-13 17:13:48,239 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-13 17:13:48,270 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-13 17:13:48,280 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-13 17:13:48,281 : INFO : EPOCH - 6 : training on 260890 raw words (185384 effective words) took 0.4s, 478977 effective words/s
# 2019-11-13 17:13:48,600 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-13 17:13:48,613 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-13 17:13:48,617 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-13 17:13:48,620 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-13 17:13:48,626 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-13 17:13:48,632 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-13 17:13:48,656 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-13 17:13:48,662 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-13 17:13:48,663 : INFO : EPOCH - 7 : training on 260890 raw words (185423 effective words) took 0.4s, 499649 effective words/s
# 2019-11-13 17:13:48,999 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-13 17:13:49,004 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-13 17:13:49,005 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-13 17:13:49,008 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-13 17:13:49,019 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-13 17:13:49,037 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-13 17:13:49,052 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-13 17:13:49,066 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-13 17:13:49,066 : INFO : EPOCH - 8 : training on 260890 raw words (185379 effective words) took 0.4s, 473000 effective words/s
# 2019-11-13 17:13:49,399 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-13 17:13:49,406 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-13 17:13:49,410 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-13 17:13:49,418 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-13 17:13:49,423 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-13 17:13:49,432 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-13 17:13:49,465 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-13 17:13:49,474 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-13 17:13:49,475 : INFO : EPOCH - 9 : training on 260890 raw words (185469 effective words) took 0.4s, 466297 effective words/s
# 2019-11-13 17:13:49,831 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-11-13 17:13:49,849 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-11-13 17:13:49,850 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-11-13 17:13:49,851 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-11-13 17:13:49,856 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-13 17:13:49,860 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-13 17:13:49,900 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-13 17:13:49,902 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-13 17:13:49,903 : INFO : EPOCH - 10 : training on 260890 raw words (185519 effective words) took 0.4s, 446307 effective words/s
# 2019-11-13 17:13:49,904 : INFO : training on a 2608900 raw words (1853917 effective words) took 4.0s, 465617 effective words/s
# (1853917, 2608900)

# %% [markdown]
# **Save to file, can be useful later**

# %%
word2vec.save("word2vecGadamer.w2v")
# Out:
# 2019-11-13 17:13:49,911 : INFO : saving Word2Vec object under word2vecGadamer.w2v, separately None
# 2019-11-13 17:13:49,912 : INFO : not storing attribute vectors_norm
# 2019-11-13 17:13:49,913 : INFO : not storing attribute cum_table
# D:\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2019-11-13 17:13:50,006 : INFO : saved word2vecGadamer.w2v

# %% [markdown]
# ## Explore the trained model.

# %%
#Load rhe trained model
word2vec = w2v.Word2Vec.load("word2vecGadamer.w2v")
# Out:
# 2019-11-13 17:13:50,012 : INFO : loading Word2Vec object from word2vecGadamer.w2v
# 2019-11-13 17:13:50,092 : INFO : loading wv recursively from word2vecGadamer.w2v.wv.* with mmap=None
# 2019-11-13 17:13:50,093 : INFO : setting ignored attribute vectors_norm to None
# 2019-11-13 17:13:50,094 : INFO : loading vocabulary recursively from word2vecGadamer.w2v.vocabulary.* with mmap=None
# 2019-11-13 17:13:50,095 : INFO : loading trainables recursively from word2vecGadamer.w2v.trainables.* with mmap=None
# 2019-11-13 17:13:50,096 : INFO : setting ignored attribute cum_table to None
# 2019-11-13 17:13:50,096 : INFO : loaded word2vecGadamer.w2v

# %%
print(word2vec.wv.most_similar('hermeneutics', topn=5))
# Out:
# 2019-11-13 17:13:50,117 : INFO : precomputing L2-norms of word weight vectors
# [('theology', 0.6939617395401001), ('theological', 0.6652019619941711), ('Protestant', 0.6600164175033569), ('positivism', 0.6594288349151611), ('philological', 0.6527665257453918)]

# %% [markdown]
# ### Compress the word vectors into 2D space and plot them

# %%
#tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)
tsne_model_en_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32)

# %%
all_word_vectors_matrix = word2vec.wv.vectors

# %% [markdown]
# **Train t-SNE, this could take a minute or two...**

# %%
all_word_vectors_matrix_2d = tsne_model_en_2d.fit_transform(all_word_vectors_matrix)

# %% [markdown]
# **Plot the big picture**

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[word2vec.wv.vocab[word].index])
            for word in word2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %%
points.head(100)
# Out:
#               word           x          y
# 0     Introduction  105.216171  -1.356095
# 1            These   -1.808463 -14.406465
# 2          studies   38.711842  53.849228
# 3              are  -58.062466 -35.456451
# 4        concerned  -14.799192 -11.020314
# 5             with  -16.270706 -12.317042
# 6              the  -25.551435  63.336555
# 7          problem   -6.412310  72.621292
# 8               of  -24.130220  64.597488
# 9     hermeneutics   49.726067  77.265327
# 10             The  -15.977891 -59.458977
# 11      phenomenon  -64.797638  44.940746
# 12   understanding  -86.586838  43.871433
# 13             and  -33.481663  10.871152
# 14         correct  -63.407269 -61.523262
# 15  interpretation   -7.575011  54.816540
# 16            what -113.659424  18.424026
# 17             has  -61.225609   0.169473
# 18            been   44.924892  53.075909
# 19      understood  -95.743042 -22.632553
# 20              is -112.664925  14.501440
# 21             not -112.653168 -11.019746
# 22               a  -68.630241  18.253117
# 23        specific  -83.993149  11.518326
# 24              to  -64.072945  -0.424140
# 25     methodology   -9.687988  94.530319
# 26           human  -13.879633  98.126198
# 27        sciences  -13.713660  97.812950
# 28           alone  -98.712189  43.522312
# 29           There  -44.214600 -18.855431
# ..             ...         ...        ...
# 70           world -100.286957  56.125347
# 71              in  -58.714779  25.018698
# 72         general  -72.639130  20.310946
# 73     hermeneutic    5.044793  89.243332
# 74       basically  -13.679850  30.422773
# 75              at  -62.487156 -92.462914
# 76             all  -86.107346 -38.164818
# 77              It  -50.880653  33.983906
# 78           means -108.631401 -19.244213
# 79       subjected  -62.639729   0.229715
# 80      scientific   -7.337934  94.577843
# 81   investigation    3.632235  88.381538
# 82            like  -60.732079 -10.751694
# 83           other  -52.577484 -72.903015
# 84         objects -102.665787  62.048866
# 85       primarily  -18.106926  48.183594
# 86        verified  -74.020699  12.057151
# 87       knowledge  -39.805111  89.568604
# 88            such  -71.471413 -21.281027
# 89           would  -66.855873 -46.350632
# 90         satisfy   23.900850  79.693939
# 91  methodological  -10.550569  96.623779
# 92           ideal  -37.829288  90.071564
# 93             yet -111.712914  -8.816076
# 94              it -112.424034  22.781839
# 95             too  -63.147568  11.744201
# 96           truth  -75.226921  65.798576
# 97              In   36.109600 -62.008526
# 98       tradition   40.226543  70.622276
# 99            only  -69.271584  16.692366
#
# [100 rows x 3 columns]

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=100, figsize=(100, 100))

# %% [markdown]
# **Zoom in to some interesting places**

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %%
plot_region(x_bounds=(120, 170), y_bounds=(-25, 25))

# %% [markdown]
# ### Explore semantic similarities

# %% [markdown]
# https://radimrehurek.com/gensim/models/word2vec.html

# %% [markdown]
# **Words closest to the given words**

# %%
word2vec.wv.most_similar("hermeneutics")
# Out:
# [('theology', 0.6939617395401001),
#  ('theological', 0.6652019619941711),
#  ('Protestant', 0.6600164175033569),
#  ('positivism', 0.6594288349151611),
#  ('philological', 0.6527665257453918),
#  ('biblical', 0.650628924369812),
#  ('philology', 0.6295825242996216),
#  ('jurisprudence', 0.6273232698440552),
#  ('triumph', 0.6135364770889282),
#  ('romantic', 0.6123664379119873)]

# %%
word2vec.wv.most_similar("language")
# Out:
# [('linguistic', 0.6164131164550781),
#  ('medium', 0.6057897806167603),
#  ('foreign', 0.604753851890564),
#  ('gesture', 0.5861180424690247),
#  ('enters', 0.5855332612991333),
#  ('entering', 0.579769492149353),
#  ('grow', 0.5773585438728333),
#  ('languages', 0.5726710557937622),
#  ('speakers', 0.565049946308136),
#  ('communication', 0.5625156164169312)]

# %%
word2vec.wv.most_similar("technology")
# Out:
# [('investigators', 0.9139717817306519),
#  ('explaining', 0.9090038537979126),
#  ('badly', 0.9080491065979004),
#  ('invoked', 0.9003320932388306),
#  ('fitted', 0.8987998962402344),
#  ('superstition', 0.897407054901123),
#  ('specialized', 0.8953264951705933),
#  ('founders', 0.8936773538589478),
#  ('inferences', 0.8930826187133789),
#  ('objectifying', 0.8912484645843506)]

# %% [markdown]
# **Linear relationships between word pairs**

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = word2vec.wv.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("language", "power", "state")
nearest_similarity_cosmul("hermeneutics", "philosophy", "truth")
nearest_similarity_cosmul("truth", "text", "language")
# Out:
# language is related to power, as occurs is related to state
# hermeneutics is related to philosophy, as texts is related to truth
# truth is related to text, as discrediting is related to language
# 'discrediting'

# %%
word2vec.wv.most_similar(positive=['language'], negative=['truth'])
# Out:
# [('linguistic', 0.3101714253425598),
#  ('Humboldt', 0.3088313341140747),
#  ('languages', 0.3015397787094116),
#  ('foreign', 0.28921735286712646),
#  ('Latin', 0.28912097215652466),
#  ('word', 0.2510349154472351),
#  ('formation', 0.20814663171768188),
#  ('Greek', 0.19917407631874084),
#  ('usage', 0.1906086653470993),
#  ('Language', 0.1819884181022644)]

# %%
word2vec.wv.most_similar(positive=['truth'], negative=['men'])
# Out:
# [('questioning', 0.40631091594696045),
#  ('philosophical', 0.3960045576095581),
#  ('claim', 0.37246373295783997),
#  ('objection', 0.3374600410461426),
#  ('intention', 0.3333823084831238),
#  ('transcendental', 0.3271540403366089),
#  ('answer', 0.32421034574508667),
#  ('Historical', 0.31538695096969604),
#  ('principle', 0.310794472694397),
#  ('raised', 0.31049269437789917)]

# %%
print(word2vec.wv.most_similar_cosmul(positive='truth', negative=None, topn=5))
# Out:
# [('progressive', 0.8384996056556702), ('Tightness', 0.8382585644721985), ('attained', 0.8366586565971375), ('claim', 0.8337680697441101), ('merge', 0.8329724669456482)]

# %% [markdown]
# Text Summarization
# This module provides functions for summarizing texts. Summarizing is based on ranks of text sentences using a variation of the TextRank algorithm.
# Federico Barrios, Federico L´opez, Luis Argerich, Rosita Wachenchauzer (2016). Variations of the Similarity Function of TextRank for Automated Summarization, https://arxiv.org/abs/1602.03606

# %%
#from gensim.summarization import summarize, keywords
#from pprint import pprint

# Summarize the paragraph
#pprint(summarize(corpus_raw, word_count=20))
#> ('the PLA Rocket Force national defense science and technology experts panel, '
#>  'according to a report published by the')

# Important keywords from the paragraph
#print(keywords(text))

# %%
# Which word from the given list doesn't go with the others?
#print(word2vec.wv.doesnt_match(['god', 'death', 'Ahab', 'Jesus', 'root']))

# %%
# Compute cosine distance between two words.
#print(word2vec.wv.distance('god', 'sun'))
#> 0.22957539558410645

# %% [markdown]
# ### Get the probability distribution of the center word given context words.

# %% [markdown]
# Parameters
#
#         context_words_list (list of str) – List of context words.
#
#         topn (int, optional) – Return topn words and their probabilities.

# %%
output_sentence = "truth and existence "
wordlist = str.split(output_sentence)
print(word2vec.predict_output_word(context_words_list=wordlist, topn=10))
# Out:
# [('language', 0.00093965104), ('own', 0.0008969674), ('truth', 0.0007870565), ('into', 0.0007516786), ('hence', 0.00069189), ('their', 0.00066980545), ('its', 0.0006252158), ('itself', 0.0006053861), ('all', 0.0005986291), ('claim', 0.0005785071)]

# %%
# Get the words closer to w1 than w2
print(word2vec.wv.words_closer_than(w1='philosophy', w2='hermeneutics'))
# Out:
# ['concept', 'science', 'Hegel', 'Kant', 'modern', 'against', 'reflection', 'view', 'thinking', 'philosophical', 'critique', 'spirit', 'fundamental', 'very', 'century', 'Husserl', 'aesthetics', 'ideas', 'transcendental', 'speculative', 'Enlightenment', 'Greek', 'development', 'certain', 'metaphysics', 'critical', 'value', 'essence', 'Ranke', 'importance', 'logical', 'doctrine', 'ultimately', 'German', 'position', 'dialectical', 'subjectivity', 'developed', 'objective', 'romantic', 'considered', 'later', 'state', 'standpoint', 'theoretical', 'recognized', 'conceived', 'conception', 'basic', 'reflective', 'school', 'influence', 'regarded', 'directed', 'origin', 'objectivity', 'nineteenth', 'starting', 'argument', 'idealism', 'system', 'age', 'historicism', 'perfect', 'beginning', 'problems', 'goes', 'Goethe', 'leads', 'methodology', 'long', 'historicity', 'metaphysical', 'justice', 'investigation', 'latter', 'society', 'allegory', 'overcome', 'Platonic', 'go', 'From', 'inasmuch', 'epistemological', 'ground', 'demand', 'systematic', 'rise', 'rhetoric', 'undoubtedly', 'last', 'eighteenth', 'His', 'valid', 'purely', 'finally', 'acquired', 'false', 'appeal', 'Being', 'worldview', 'faith', 'intellectual', 'consequence', 'radical', 'led', 'foundation', 'recognition', 'return', 'attempt', 'decisive', 'achievement', 'early', 'claims', 'culture', 'justification', 'superior', 'role', 'definition', 'religion', 'close', 'ancient', 'came', 'background', 'became', 'antiquity', 'attitude', 'abstract', 'conclusion', 'antithesis', 'considers', 'sought', 'Since', 'stands', 'construction', 'rational', 'priori', 'tendency', 'presupposition', 'identity', 'concern', 'naive', 'cf', 'emphasized', 'consequences', 'period', 'soul', 'Vico', 'contained', 'phenomenology', 'starts', 'formal', 'virtue', 'follow', 'Critique', 'gave', 'certainty', 'tragedy', 'legitimacy', 'traditional', 'pre', 'psychology', 'empirical', 'transition', 'central', 'tried', 'viewpoint', 'Kantian', 'Fichte', 'Aristotelian', 'hidden', 'going', 'symbolic', 'Yorck', 'particularly', 'awareness', 'ethics', 'opposed', 'get', 'Time', 'philology', 'took', 'necessity', 'comprehensive', 'level', 'Although', 'applies', 'Schiller', 'schema', 'myth', 'step', 'justified', 'phenomenological', 'term', 'raises', 'church', 'reveals', 'realm', 'superseded', 'times', 'Western', 'revealed', 'objection', 'constitution', 'proof', 'accident', 'conceive', 'ontology', 'superiority', 'effective', 'manner', 'almost', 'absolutely', 'path', 'rhetorical', 'dominated', 'fulfillment', 'progress', 'opposition', 'grounding', 'Herder', 'offers', 'measure', 'hold', 'enlightenment', 'late', 'shares', 'Lowith', 'aim', 'establish', 'earlier', 'immanent', 'inevitably', 'seemed', 'formulation', 'unconscious', 'moves', 'move', 'derives', 'According', 'philological', 'criteria', 'explicit', 'area', 'neo', 'dogmatics', 'provide', 'Leibniz', 'weakness', 'proved', 'famous', 'interests', 'relativity', 'Dialectic', 'induction', 'sounds', 'corresponding', 'ideality', 'difficulty', 'mythical', 'until', 'objectivism', 'confusion', 'heritage', 'face', 'aspects', 'recognizing', 'changed', 'emergence', 'mathematical', 'Roman', 'proposition', 'conceives', 'followed', 'tied', 'cultivation', 'rationalism', 'previous', 'Shaftesbury', 'worked', 'alienation', 'substance', 'experiment', 'reversal', 'admit', 'develop', 'lost', 'Nor', 'romanticism', 'humanistic', 'remained', 'justify', 'sufficient', 'heart', 'introduced', 'overcoming', 'elaborated', 'held', 'likewise', 'sometimes', 'holds', 'implicit', 'beginnings', 'years', 'teaches', 'implied', 'True', 'probably', 'English', 'idealistic', 'center', 'empiricism', 'influenced', 'humanity', 'profound', 'medieval', 'morality', 'clarity', 'taught', 'productivity', 'Winckelmann', 'Schelling', 'ontologically', 'least', 'humanism', 'cultural', 'education', 'showing', 'aims', 'physics', 'conclusions', 'Reason', 'began', 'emphasizes', 'simple', 'classicism', 'Phenomenology', 'explain', 'founded', 'direct ...

# %% [markdown]
# ## Find a word in the plot

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[word2vec.wv.vocab[word].index])
            for word in word2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %% [markdown]
# We search for a certain "centerword" in our Dataframe and add '(?:\s|$)' as empty space behind the word, otherwise we will also get matches IN an word as return.

# %%
centerword = "truth"
df = points
df[df['word'].str.match(centerword + '(?:\s|$)')]
value_x = df.loc[df['word'].str.match(centerword + '(?:\s|$)'), 'x'].values[0]
value_y = df.loc[df['word'].str.match(centerword + '(?:\s|$)'), 'y'].values[0]
print(value_x, value_y)
# Out:
# -75.22692108154297 65.79857635498047

# %% [markdown]
# The values are used to built a plot with a certain width around this word.

# %%
#value_x = -36.29
#value_y = -89.17
width = 10

def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 10))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.008, point.y + 0.008, point.word, fontsize=11)

plot_region(x_bounds=(value_x-width/2, value_x+width/2), y_bounds=(value_y-width/2, value_y+width/2))

# %% [markdown]
# ## Word Clusters

# %%
keys = ['language', 'state', 'philosophy', 'death', 'Hegel', 'technology', 'language', 'word']

embedding_clusters = []
word_clusters = []
for word in keys:
    embeddings = []
    words = []
    for similar_word, _ in word2vec.wv.most_similar(word, topn=30):
        words.append(similar_word)
        embeddings.append(word2vec[similar_word])
    embedding_clusters.append(embeddings)
    word_clusters.append(words)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.

# %%
embedding_clusters = np.array(embedding_clusters)
n, m, k = embedding_clusters.shape
tsne_model_en_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32)
embeddings_en_2d = np.array(tsne_model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))).reshape(n, m, 2)

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')

def tsne_plot_similar_words(title, labels, embedding_clusters, word_clusters, a, filename=None):
    plt.figure(figsize=(16, 9))
    colors = cm.rainbow(np.linspace(0, 1, len(labels)))
    for label, embeddings, words, color in zip(labels, embedding_clusters, word_clusters, colors):
        x = embeddings[:, 0]
        y = embeddings[:, 1]
        plt.scatter(x, y, c=color, alpha=a, label=label)
        for i, word in enumerate(words):
            plt.annotate(word, alpha=0.5, xy=(x[i], y[i]), xytext=(5, 2),
                         textcoords='offset points', ha='right', va='bottom', size=8)
    plt.legend(loc=4)
    plt.title(title)
    plt.grid(True)
    if filename:
        plt.savefig(filename, format='png', dpi=150, bbox_inches='tight')
    plt.show()


tsne_plot_similar_words('Similar words in the Bible', keys, embeddings_en_2d, word_clusters, 0.2,
                        'similar_words.png')

# %%
cluster_table = pd.DataFrame(word_clusters, keys)
cluster_table
# Out:
#                        0             1              2             3   \
# language       linguistic        medium        foreign       gesture
# state             affairs        powers       sympathy     genuinely
# philosophy            neo    idealistic     Kantianism  spiritualism
# death           abolition  transparency      enjoyment    undergoing
# Hegel         dialectical   speculative  Phenomenology    opposition
# technology  investigators    explaining          badly       invoked
# language       linguistic        medium        foreign       gesture
# word               verbum       mystery         mirror   incarnation
#
#                    4                 5            6             7   \
# language       enters          entering         grow     languages
# state       coincides            evolve    operative      category
# philosophy    satisfy  subjectivization  polemically       sophism
# death        adoption          eventual      neutral       soaring
# Hegel            Mind          idealism        Yorck         Ranke
# technology     fitted      superstition  specialized      founders
# language       enters          entering         grow     languages
# word            forma           Trinity        image  metaphorical
#
#                       8              9   ...           20               21  \
# language        speakers  communication  ...         fall           spoken
# state          senseless         arouse  ...  instinctive            cause
# philosophy      Hegelian       idealism  ...        pride      speculation
# death            opening        expands  ...  aprioristic       separation
# Hegel       convincingly         Lowith  ...      Ancient  intellectualism
# technology    inferences   objectifying  ...     adopting        compelled
# language        speakers  communication  ...         fall           spoken
# word                 Son          onoma  ...        usage           divine
#
#                       22              23            24             25  \
# language       customary     transformed   strangeness   idealization
# state              grows           Using    subsequent  communicative
# philosophy  subjectivism     metaphysics    divergence    rationalism
# death              truer      culminates  unmistakable    culminating
# Hegel              Ideas  determinations        adopts         hybrid
# technology       efforts          hybrid    compelling    meteorology
# language       customary     transformed   strangeness   idealization
# word               unity           schon      mirrored           verb
#
#                       26           27           28                29
# language     factualness   imprisoned        prose          reaching
# state             effort      society  nonsensible  unconditionality
# philosophy     dominance   classicist     Kantians            defend
# death              drive       climax     boundary             First
# Hegel             Fichte     Schiller      seduced              Five
# technology          anti  unjustified     banished       endeavoring
# language     factualness   imprisoned        prose          reaching
# word        substitution       refers     intimate           erleben
#
# [8 rows x 30 columns]

# %%
tsne_wp_3d = TSNE(perplexity=10, n_components=3, init='pca', n_iter=3500, random_state=12)
embeddings_wp_3d = tsne_wp_3d.fit_transform(all_word_vectors_matrix)

from mpl_toolkits.mplot3d import Axes3D


def tsne_plot_3d(title, label, embeddings, a=1):
    fig = plt.figure()
    ax = Axes3D(fig)
    colors = cm.rainbow(np.linspace(0, 1, 1))
    plt.scatter(embeddings[:, 0], embeddings[:, 1], embeddings[:, 2], c=colors, alpha=a, label=label)
    plt.legend(loc=2)
    plt.title(title)
    plt.show()


tsne_plot_3d('Visualizing Embeddings using t-SNE', 'bible', embeddings_wp_3d, a=0.1)
# Out:
# D:\Anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
